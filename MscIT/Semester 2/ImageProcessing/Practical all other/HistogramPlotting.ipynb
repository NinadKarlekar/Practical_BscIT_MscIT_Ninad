# %% [markdown]
# # Histogram equolizaion

# %% [markdown]
# ### Plotting Histogram for High Contrast Image

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('F:/GitHub/Practical_BscIT_MscIT_Ninad/MscIT/Semester 2/ImageProcessing/Dataset/HighContrast.jfif',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
#plt.imshow(img)
plt.plot(histr)
plt.show()

# %% [markdown]
# ---------------------
#
# ### Plotting Histogram for Low Contrast Image

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('F:/GitHub/Practical_BscIT_MscIT_Ninad/MscIT/Semester 2/ImageProcessing/Dataset/LowContrast.jfif',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
#plt.imshow(img)
plt.plot(histr)
plt.show()

# %% [markdown]
# -------------------------------------
#
# ### Plotting Histogram for Dark Image

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('F:/GitHub/Practical_BscIT_MscIT_Ninad/MscIT/Semester 2/ImageProcessing/Dataset/Dark.png',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
#plt.imshow(img)
plt.plot(histr)
plt.show()

# %% [markdown]
# -----------------------------------------------
#
# ### Plotting Histogram for Bright Image

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('F:/GitHub/Practical_BscIT_MscIT_Ninad/MscIT/Semester 2/ImageProcessing/Dataset/Bright.png',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
#plt.imshow(img)
plt.plot(histr)
plt.show()
